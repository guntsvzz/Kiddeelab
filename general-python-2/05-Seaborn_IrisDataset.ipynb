# %% [markdown]
# # Seaborn

# %%
# !pip install seaborn
# !pip install scikit-learn
# ref https://www.shecancode.io/blog/univariate-and-bivariate-analysis-usingseaborn

# %%
import seaborn as sns
import pandas as pd
from sklearn.datasets import load_iris
import warnings
warnings.filterwarnings('ignore')

# %%
# Load the Iris dataset
iris = load_iris()
# Create a DataFrame
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
# Add the target variable to the DataFrame
df['target'] = iris.target
df['target'] = df['target'].map({i: name for i, name in enumerate(iris.target_names)})
# Print the first few rows of the DataFrame
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
df.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target'],
#       dtype='object')

# %% [markdown]
# ## histplot

# %%
sns.histplot(df["sepal length (cm)"],color='darkorange')
# Out:
# <Axes: xlabel='sepal length (cm)', ylabel='Count'>

# %%
sns.histplot(y="sepal length (cm)",data=df,color='darkorange')
# Out:
# <Axes: xlabel='Count', ylabel='sepal length (cm)'>

# %%
sns.histplot(x='sepal length (cm)',data=df,hue=df['target'])
# Out:
# <Axes: xlabel='sepal length (cm)', ylabel='Count'>

# %% [markdown]
# ## distplot

# %%
sns.distplot(df["sepal length (cm)"],color='darkorange')
# Out:
# <Axes: xlabel='sepal length (cm)', ylabel='Density'>

# %%
sns.distplot(df["sepal length (cm)"],hist=False,color='darkorange')
# Out:
# <Axes: xlabel='sepal length (cm)', ylabel='Density'>

# %% [markdown]
# ## boxplot

# %%
sns.boxplot(df["sepal length (cm)"],color='darkorange')
# Out:
# <Axes: >

# %% [markdown]
# ## countplot

# %%
sns.countplot(x= df['target'])
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %% [markdown]
# ## barplot

# %%
sns.barplot(x='target',y='sepal length (cm)',data=df)
# Out:
# <Axes: xlabel='target', ylabel='sepal length (cm)'>

# %% [markdown]
# ## pointplot

# %%
sns.pointplot(x='target',y='petal width (cm)',data=df,color='darkorange')
# Out:
# <Axes: xlabel='target', ylabel='petal width (cm)'>

# %% [markdown]
# ## scatterplot

# %%
sns.scatterplot(df["petal length (cm)"],df['petal width (cm)'],color='darkorange')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 sns.scatterplot(df["petal length (cm)"],df['petal width (cm)'],color='darkorange')
#
# TypeError: scatterplot() takes from 0 to 1 positional arguments but 2 were given

# %% [markdown]
# ## lineplot

# %%
sns.lineplot(df['petal length (cm)'],df['petal width (cm)'],color='darkorange')
# Out:
# c:\Python3.10.4\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='petal length (cm)', ylabel='petal width (cm)'>

# %% [markdown]
# ## regplot

# %%
sns.regplot(df['petal length (cm)'],df['petal width (cm)'],color='darkorange')
# Out:
# c:\Python3.10.4\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='petal length (cm)', ylabel='petal width (cm)'>
